# %%
import pandas as pd
a={'roll no':[1,2,3,4],'name':["anu","aju","afi","ami"]}
print(a)
b=pd.DataFrame(a)
print(b)
# Out:
# {'roll no': [1, 2, 3, 4], 'name': ['anu', 'aju', 'afi', 'ami']}
#    roll no name
# 0        1  anu
# 1        2  aju
# 2        3  afi
# 3        4  ami

# %%
import pandas as pd
a=[1,2,3,4]
b=pd.Series(a)
print(b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
import pandas as pd
a={'roll no':[1,2,3,4],'name':["anu","aju","afi","ami"]}
#print(a)
b=pd.DataFrame(a)
print(b.loc[1])
# Out:
# roll no      2
# name       aju
# Name: 1, dtype: object

# %%
import pandas as pd
a=pd.read_csv('data.csv')
print(a)
# Out:
#   name  age  gender
# 0  aju   26    male
# 1  anu   23  female
# 2  afi   21    male

# %%
import pandas as pd
a=pd.read_csv('data.csv')
print(a.head(2))
# Out:
#   name  age  gender
# 0  aju   26    male
# 1  anu   23  female

# %%
import pandas as pd
a=pd.read_csv('data.csv')
print(a.tail(1))
# Out:
#   name  age gender
# 2  afi   21   male

# %%
import pandas as pd
a=pd.read_csv('data.csv')
print(a.dropna())
# Out:
#   name  age  gender
# 0  aju   26    male
# 1  anu   23  female
# 2  afi   21    male
