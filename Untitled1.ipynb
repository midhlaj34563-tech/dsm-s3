# %%
import numpy as np
a=np.array([[1,2],[4,3]])
b=np.array([[5,6],[7,8]])
add=a+b
print("addition",add)
sub=a-b
print("substraction",sub)
mul=a*b
print ("multiplication",mul)

a@b
print(np.transpose(a))
# Out:
# addition [[ 6  8]
#  [11 11]]
# substraction [[-4 -4]
#  [-3 -5]]
# multiplication [[ 5 12]
#  [28 24]]
# [[1 4]
#  [2 3]]
