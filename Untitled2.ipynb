# %%
import matplotlib.pyplot as plt
x=[3,5,6,9,7,5]
y=[8,6,5,7,2,6]
plt.title("PLOt")
plt.xlabel("number of students")
plt.ylabel("subjects")
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
subjects=["arabic","hindi","css","java"]
marks=[60,40,50,60]
plt.title("BAR CHART")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.bar(subjects,marks)
# Out:
# <BarContainer object of 4 artists>
